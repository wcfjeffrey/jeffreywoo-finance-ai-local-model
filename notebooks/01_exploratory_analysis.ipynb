# %% [markdown]
# # HSI Stock Prediction - Exploratory Analysis

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Load HSI data
tencent = yf.download('0700.HK', period='1y')
tencent['Close'].plot(title='Tencent Stock Price')
plt.show()
